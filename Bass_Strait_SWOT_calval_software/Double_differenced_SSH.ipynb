# %%
### set up the notebook
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from scipy.interpolate import griddata
import scipy.stats as stats
from scipy.optimize import curve_fit

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
np.set_printoptions(linewidth=100) 

plt.rcParams.update({'font.size': 16})
# Out:
# <style>.container { width:90% !important; }</style>

# %%
def remove_outliers_IQR(data, limit):
    len_nan = len(data[np.isnan(data)])
    q1 = np.nanpercentile(data, 25)
    q3 = np.nanpercentile(data, 75)
    iqr = q3 - q1
    lower_bound = q1 - limit * iqr
    upper_bound = q3 + limit * iqr
    # where data is outside bounds, replace with nan
    data_cp = data.copy()
    data_cp[(data_cp < lower_bound) | (data_cp > upper_bound)] = np.nan
    print('Removed %d / %d points' % (np.sum(np.isnan(data_cp))-len_nan, len(data.flatten())))
    return data_cp


# Define a model: a * log10(x) + b
def model(x, a, b):
    return a * np.log10(x) + b

# Bisquare weighting function
def bisquare_weight(residuals, c=1.0):
    # Bisquare weight: 1 - (residuals / c)^2 for residuals < c, else 0
    weights = np.ones_like(residuals)
    mask = np.abs(residuals) <= c
    weights[mask] = (1 - (residuals[mask] / c)**2)**2
    return weights

# Perform the fitting with robust bisquare weighting
def robust_fit(x_data, y_data, model, initial_params, maxiter=1, c=1.0):
    # Initial parameter guess for a and b
    params = initial_params
    
    for _ in range(maxiter):
        # Calculate the model predictions
        y_pred = model(x_data, *params)
        
        # Calculate residuals
        residuals = y_data - y_pred
        
        # Get weights using bisquare weighting
        weights = bisquare_weight(residuals, c)
        
        # Perform weighted least squares fit (using curve_fit)
        popt, _ = curve_fit(model, x_data, y_data, p0=params, sigma=weights, absolute_sigma=True)
        params = popt  # Update parameters

    return params

# %%
### load the data
# GNSS
GNSS = np.genfromtxt('GNSS_at_SWOT_times_SSH_only.csv', delimiter=",")
# SWOT (2km and unsmoothed)
SWOT = np.genfromtxt('SWOT_at_buoys_SSH_only.csv', delimiter=",")
SWOT_us = np.genfromtxt('SWOT_unsmoothed_SSH_only.csv', delimiter=",")
# load coordinates
coords = np.genfromtxt('buoy_locations_FSP_UTM.csv', delimiter=",")

# %%
# convert m to cm
GNSS = GNSS*100
SWOT = SWOT*100
SWOT_us = SWOT_us*100

# %%
# calculate double differences
resids = SWOT - GNSS
resids_us = SWOT_us - GNSS

# calculate pairwise diffs
GNSS_diffs = np.ones((36, 96))*np.nan
SWOT_diffs = np.ones((36, 96))*np.nan
SWOT_us_diffs = np.ones((36, 96))*np.nan
distances = np.ones((36))*np.nan

# Generate unique pairs of indices
pairs = [(i, j) for i in range(9) for j in range(i + 1, 9)]

# Calculate pairwise differences for the unique pairs
for idx, (i, j) in enumerate(pairs):
    GNSS_diffs[idx, :] = (GNSS[i, :] - GNSS[j, :])
    SWOT_diffs[idx, :] = (SWOT[i, :] - SWOT[j, :])
    SWOT_us_diffs[idx, :] = (SWOT_us[i, :] - SWOT_us[j, :])
    distances[idx] = np.sqrt((coords[i, 0] - coords[j, 0])**2 + (coords[i, 1] - coords[j, 1])**2)

# convert distances to km
distances = distances/1000

# calculate the pairwise double differences
double_diffs = SWOT_diffs - GNSS_diffs
double_diffs_us = SWOT_us_diffs - GNSS_diffs

# remove cycles with all NaNs
columns_to_keep = ~np.isnan(double_diffs).all(axis=0)
double_diffs = double_diffs[:, columns_to_keep]
columns_to_keep = ~np.isnan(double_diffs_us).all(axis=0)
double_diffs_us = double_diffs_us[:, columns_to_keep]

# %%
### remove outliers

double_diffs_clean = []
double_diffs_us_clean = []

for i in range(36):
    tmp_double_diffs_clean = remove_outliers_IQR(double_diffs[i,:], 1.5)
    double_diffs_clean.append(tmp_double_diffs_clean)
    tmp_double_diffs_us_clean = remove_outliers_IQR(double_diffs_us[i,:], 1.5)
    double_diffs_us_clean.append(tmp_double_diffs_us_clean)
    
double_diffs_clean = np.array(double_diffs_clean)
dd_std_clean = np.nanstd(double_diffs_clean, axis=1)/np.sqrt(2)
double_diffs_us_clean = np.array(double_diffs_us_clean)
dd_std_us_clean = np.nanstd(double_diffs_us_clean, axis=1)/np.sqrt(2)
# Out:
# Removed 0 / 88 points
# Removed 3 / 81 points
# Removed 5 / 88 points
# Removed 5 / 81 points
# Removed 1 / 88 points
# Removed 4 / 81 points
# Removed 3 / 88 points
# Removed 2 / 81 points
# Removed 0 / 88 points
# Removed 2 / 81 points
# Removed 1 / 88 points
# Removed 3 / 81 points
# Removed 2 / 88 points
# Removed 2 / 81 points
# Removed 3 / 88 points
# Removed 3 / 81 points
# Removed 5 / 88 points
# Removed 0 / 81 points
# Removed 3 / 88 points
# Removed 0 / 81 points
# Removed 5 / 88 points
# Removed 1 / 81 points
# Removed 1 / 88 points
# Removed 1 / 81 points
# Removed 1 / 88 points
# Removed 3 / 81 points
# Removed 2 / 88 points
# Removed 0 / 81 points
# Removed 0 / 88 points
# Removed 1 / 81 points
# Removed 5 / 88 points
# Removed 1 / 81 points
# Removed 2 / 88 points
# Removed 0 / 81 points
# Removed 0 / 88 points
# Removed 0 / 81 points
# Removed 1 / 88 points
# Removed 1 / 81 points
# Removed 5 / 88 points
# Removed 4 / 81 points
# Removed 1 / 88 points
# Removed 1 / 81 points
# Removed 4 / 88 points
# Removed 1 / 81 points
# Removed 1 / 88 points
# Removed 0 / 81 points
# Removed 0 / 88 points
# Removed 2 / 81 points
# Removed 5 / 88 points
# Removed 2 / 81 points
# Removed 1 / 88 points
# Removed 7 / 81 points
# Removed 8 / 88 points
# Removed 0 / 81 points
# Removed 1 / 88 points
# Removed 3 / 81 points
# Removed 2 / 88 points
# Removed 0 / 81 points
# Removed 5 / 88 points
# Removed 7 / 81 points
# Removed 3 / 88 points
# Removed 1 / 81 points
# Removed 8 / 88 points
# Removed 2 / 81 points
# Removed 4 / 88 points
# Removed 3 / 81 points
# Removed 3 / 88 points
# Removed 4 / 81 points
# Removed 4 / 88 points
# Removed 4 / 81 points
# Removed 0 / 88 points
# Removed 1 / 81 points

# %%
# calculate fit

fig_width = 17.4
plt.rcParams.update({'font.size': 18})

# sort data by distance
sort_idx = np.argsort(distances)
distance_sort = distances[sort_idx]
dd_std_clean_sort = dd_std_clean[sort_idx]
dd_std_us_clean_sort = dd_std_us_clean[sort_idx]
x_data = distance_sort
y_data = dd_std_clean_sort
y_data2 = dd_std_us_clean_sort


# Initial guess for parameters a and b
initial_guess = [1.0, 0.1]

# Fit the model using the robust fitting function
params_fit = robust_fit(x_data, y_data, model, initial_guess)
params_fit2 = robust_fit(x_data, y_data2, model, initial_guess)

# Extract the fitted parameters
a_fit, b_fit = params_fit
a_fit2, b_fit2 = params_fit2

fitted_model = model(x_data, *params_fit)
fitted_model_us = model(x_data, *params_fit2)


insitu_error = 4.6


# Plotting the data and the fitted curve
fig, ax = plt.subplots(1, figsize=(fig_width,7))
plt.scatter(x_data, y_data*10, label='SWOT 2 km - GNSS buoy SSH', color='C0', s=50, zorder=10)
plt.plot(x_data, fitted_model*10, color='C0', lw=3, alpha=0.5, linestyle='--')
plt.scatter(x_data, y_data2*10, label='SWOT umsmoothed - GNSS buoy SSH', color='silver', s=50, zorder=1)
plt.plot(x_data, fitted_model_us*10,   color='silver', lw=3, alpha=0.5, linestyle='--')
plt.xlabel('Separation Distance (km)')
plt.ylabel("Double Difference \nStandard Deviation / $\sqrt{2}$ (mm)")
ax.grid(linestyle='--', alpha=0.5)
ax.set_ylim(0, 28)
ax.set_xlim(0, 85)

ax.plot([0,4], [insitu_error, insitu_error], c='k', linestyle='--', alpha=0.7)
plt.legend(loc='upper left')

props = dict(facecolor='white',  edgecolor='w')
text = f"GNSS differential SSH\nuncertainty = {insitu_error:.1f} mm"
ax.text(0.055, 0.1, text, transform=ax.transAxes, bbox=props, alpha=0.7)

plt.tight_layout()
plt.show()

# %%
### total error over 10 km

total_2km = np.nanmean(y_data[0:3])
total_us = np.nanmean(y_data2[0:3])
print('total error over 10 km for 2 km product: %0.2f cm' % (total_2km))
print('total error over 10 km for unsmoothed product: %0.2f cm' % (total_us))
# Out:
# total error over 10 km for 2 km product: 0.84 cm
# total error over 10 km for unsmoothed product: 1.38 cm

# %%
### total error over 80 km

print('total error over 80 km for 2 km product: %0.2f cm' % (np.nanmean(y_data[-2::])))
print('total error over 80 km for unsmoothed product: %0.2f cm' % (np.nanmean(y_data2[-2::])))
# Out:
# total error over 80 km for 2 km product: 1.77 cm
# total error over 80 km for unsmoothed product: 2.01 cm

# %%
### SWOT error contribution, assuming insitu contribution = insitu_error
insitu_error = 4.6

SWOT_error_2km_upper = np.sqrt(total_2km**2 - (insitu_error/10)**2)
SWOT_error_us_upper = np.sqrt(total_us**2 - (insitu_error/10)**2)
print('UPPER BOUND')
print('SWOT error over 10 km for 2 km product: %0.2f cm' % (SWOT_error_2km_upper))
print('SWOT error over 10 km for unsmoothed product: %0.2f cm' % (SWOT_error_us_upper))
# Out:
# UPPER BOUND
# SWOT error over 10 km for 2 km product: 0.70 cm
# SWOT error over 10 km for unsmoothed product: 1.30 cm

# %%
### SWOT error contribution, assuming factor 6 relationship between 2 km and unsmoothed

SWOT_error_2km_lower = np.sqrt((total_us**2 - total_2km**2)/35)
SWOT_error_us_lower = SWOT_error_2km_lower*6
GNSS_error_1 = np.sqrt(total_2km**2 - SWOT_error_2km_lower**2) 
GNSS_error_2 = np.sqrt(total_us**2 - SWOT_error_us_lower**2) 

print('LOWER BOUND')
print('SWOT error over 10 km for 2 km product: %0.2f cm' % (SWOT_error_2km_lower))
print('SWOT error over 10 km for unsmoothed product: %0.2f cm' % (SWOT_error_us_lower))
print('check GNSS error: %0.2f cm, %0.2f cm' % (GNSS_error_1, GNSS_error_2))
# Out:
# LOWER BOUND
# SWOT error over 10 km for 2 km product: 0.18 cm
# SWOT error over 10 km for unsmoothed product: 1.11 cm
# check GNSS error: 0.82 cm, 0.82 cm

# %%
### SWOT error contribution, assuming factor 6 relationship between 2 km and unsmoothed at 80 km

SWOT_error_2km_lower = np.sqrt(((np.nanmean(y_data2[-2:-1]))**2 - (np.nanmean(y_data[-2:-1]))**2)/35)
SWOT_error_us_lower = SWOT_error_2km_lower*6
GNSS_error_1 = np.sqrt((np.nanmean(y_data[-2:-1]))**2 - SWOT_error_2km_lower**2) 
GNSS_error_2 = np.sqrt((np.nanmean(y_data2[-2:-1]))**2 - SWOT_error_us_lower**2) 

print('LOWER BOUND')
print('SWOT error over 80 km for 2 km product: %0.2f cm' % (SWOT_error_2km_lower))
print('SWOT error over 80 km for unsmoothed product: %0.2f cm' % (SWOT_error_us_lower))
print('check GNSS error: %0.2f cm, %0.2f cm' % (GNSS_error_1, GNSS_error_2))
# Out:
# LOWER BOUND
# SWOT error over 80 km for 2 km product: 0.22 cm
# SWOT error over 80 km for unsmoothed product: 1.34 cm
# check GNSS error: 1.68 cm, 1.68 cm
